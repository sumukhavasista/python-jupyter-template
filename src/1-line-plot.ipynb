# %% [markdown]
# ### Exercise 1: Line Plot Customization

# %%
# TASK: Create a line plot with x values ranging from 0 to 10 and y values as the square of x.
# Customize the plot by adding a title, labels for both axes, and a grid.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)
y = x ** 2

# %%
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='y = x²', color='blue', linewidth=2)

# %%
plt.title("Line Plot of y = x²", fontsize=14)
plt.xlabel("X Values", fontsize=12)
plt.ylabel("Y Values", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
# Out:
# /tmp/ipykernel_5591/1274161615.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.show()
